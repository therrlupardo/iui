# %%
import tensorflow as tf
from utils import HelperUtils
model = tf.keras.models.load_model('./models/initial_model.h5')

HelperUtils.test(model, None)
# Out:
# ...
# 32768/17378 [========================================================] - 0s 0us/step
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=456x715 at 0x21E22050A60>
# This image most likely belongs to 250 with a 94.30 percent confidence.

# %%
model = tf.keras.models.load_model('./models/initial_model.h5')

HelperUtils.test(model, None)
# Out:
# [array([[[[ 0.34433085, -1.2262123 ,  0.02306195,  0.07615667,
#            -0.0411251 ,  0.32069993, -0.1310494 , -0.30502614,
#            -0.10129321, -0.17378093, -0.03375688, -0.0038406 ,
#            -0.07360766, -0.05328079, -0.4105438 , -0.15424792],
#           [ 0.27425778, -0.3854631 , -0.21323887,  0.02921241,
#            -0.09006634,  0.1927876 , -0.386492  ,  0.18751869,
#            -0.22234812,  0.05348425, -0.09673756,  0.06125138,
#            -0.11451533, -0.13072792, -0.15257552,  0.05613942],
#           [ 0.33697954, -1.3665783 , -0.19268307, -0.0797063 ,
#            -0.1001583 ,  0.35054693, -0.588759  ,  0.18142201,
#            -0.0580169 , -0.21371333,  0.0836463 , -0.04639091,
#             0.11896509, -0.01760585, -0.28947708, -0.09624607]],
#
#          [[ 0.06188161, -1.52753   ,  0.12204672, -0.12901591,
#             0.07751066,  0.14167786, -0.5242737 , -0.20669189,
#            -0.01885539, -0.02956911,  0.03329978, -0.22693725,
# ...
